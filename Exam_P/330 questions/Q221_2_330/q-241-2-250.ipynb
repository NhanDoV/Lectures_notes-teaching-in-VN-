# %% [markdown]
# [Referenced document](https://github.com/Nhan121/Lectures_notes-teaching-in-VN-/blob/master/Exam_P/330%20questions/330-questions.pdf)
#
# Lưu ý. Các ký hiệu và từ viết tắt trong file mang hướng cá nhân và bài giải cũng hướng đến một nhóm đối tượng trong chuyên ngành hẹp, không phải đại chúng,
#
# --------------------------------

# %% [markdown]
# #### Question 241,
# Losses covered by an insurance policy are modeled by a **uniform distribution** on the interval $[0, 1000]$. An insurance company reimburses losses in excess of a deductible of $250.$
#
# Calculate the difference between the median and the $20^{th}$ percentile of the insurance company reimbursement, over all losses.

# %% [markdown]
# **Giải đáp / SOLUTIONs.**
#
# Đặt $X$ là mức tổn thất, theo đó $X \sim \mathcal{U}([0, 1000])$ và $Y = \max(0, X-250)$ là mức bồi thường mà BH sẽ chi trả. Tổng quát, ta có
#
# $$ P[X \leq x] = \left\lbrace \begin{array}{rl} 0,& x < 0 \\ \dfrac{x}{1000} & x \in [0, 1000] \\ 1, & x > 1000. \end{array} \right. $$
# do đó
# - phân vi mức $20\%$ của $X$ sẽ thỏa $\dfrac{x_p}{1000} = 0.20 \Longrightarrow x_p = 200$.
# - tương tự; trung vị của $X$ sẽ thỏa $\dfrac{x_m}{1000} = 0.50 \Longrightarrow x_m = 500$.
#
# Vì $Y = \max(0, X-250)$ nên các phân vị tương ứng của $Y$ sẽ xác định theo $X$ thông qua hệ thức
#
# $$ y_p = \max(0, x_p - 250) = 0 $$
# và
# $$ y_m = \max(0, x_m - 250) = 250 $$
# Do đó; hiệu số cần tìm là
#
# $$ y_m - y_p = 250. $$

# %% [markdown]
# #### Question 242.
# The annual profits that company A and company B earn follow a **bivariate normal distribution**.
# - Company A's annual profit has mean 2000 and standard deviation 1000.
# - Company B's annual profit has mean 3000 and standard deviation 500.
# - The correlation coefficient between these annual profits is 0.80.
#
# Calculate the probability that company B's annual profit is less than 3900, given that company A's annual profit is 2300.

# %% [markdown]
# **Giải đáp / SOLUTIONs.**
#
# Trình tự lý luận:
# - Đặt $X, Y$ lần lượt là lợi nhuận hàng năm ở các cty $A$ và $B$; khi đó $(X,Y) \sim \mathcal{N}_2 \left( \mu, \Sigma \right)$ với
#
# $$ \mu = \left( \mu_X, \mu_Y \right)^T, \qquad \Sigma = \left( \begin{array}{cc} \sigma_X^2 & \rho_{XY} \\ \rho_{XY} & \sigma_Y^2 \end{array} \right) $$
# - 3 giả thiết còn lại cho biết
# $$ \begin{array}{rll} \text{Theo (i),} & \mu_X = 2000, & \sigma_X = 1000 \\ \text{(ii),} & \mu_Y = 3000, & \sigma_Y = 500 \\ \text{(iii),} & \dfrac{\rho_{XY}}{\sigma_X \sigma_Y} = 0.8 \end{array} $$
# - BT yêu cầu tính XS để lợi nhuận cty B thấp hơn 3900 biết rằng lợi nhuận cty A bằng 2300; tức là $P[Y < 3900 | X = 2300]$
# - **Kiến thức ở thống kê nhiều biến [Multivariate Statistics]. Nếu $Z = (X,Y)$ có phân phối chuẩn 2 chiều $\mathcal{N}_2\left( \mu, \Sigma \right)$ thì BNN có điều kiện $(Y|X=x_0)$ sẽ có phân phối chuẩn và xác định bởi**
#
# $$ (Y|X=x_0) \sim \mathcal{N} \left( \mu_Y + \dfrac{r_{XY} \cdot \sigma_Y}{\sigma_X}\left(x_0 - \mu_X \right), \;\; \sigma_Y^2 \left( 1 - r_{XY}^2 \right) \right) $$
# trong đó $$ r_{XY} = \dfrac{\rho_{XY}}{\sigma_X \sigma_Y} $$
# - Quay lại bài toán; thay các giá trị trong giả thiết vào; ta có $r_{XY} = 0.8$ và
#
# $$ \begin{array}{rllcl} \mu_Y + \dfrac{r_{XY} \cdot \sigma_Y}{\sigma_X}\left(x_0 - \mu_X \right) &=& 3000 + \dfrac{(0.8)\cdot 500}{1000}(2300 - 2000) &=& 3120 \\ \sigma_Y^2 \left( 1 - r_{XY}^2 \right) &=& (500)^2 (1 - (0.8)^2) &=& 90000. \end{array} $$
# do đó
#
# $$ \begin{array}{ccl} P[Y < 3900 | X = 2300] &=& P\left( \mathcal{N}(3120, 90000) < 3900 \right) \\ &=& P\left( \mathcal{N}(0, 1) < \dfrac{3900 - 3120}{\sqrt{90000}} \right) \\ &=& \Phi(2.6) \\ &=& 0.9953. \end{array}$$

# %% [markdown]
# #### Question 243.
# An insurance agent’s files reveal the following facts about his policyholders:
# - i) 243 own auto insurance.
# - ii) 207 own homeowner insurance.
# - iii) 55 own life insurance and homeowner insurance.
# - iv) 96 own auto insurance and homeowner insurance.
# - v) 32 own life insurance, auto insurance and homeowner insurance.
# - vi) 76 more clients own only auto insurance than only life insurance.
# - vii) 270 own only one of these three insurance products.
#
# Calculate the total number of the agent’s policyholders who own at least one of these three insurance products.

# %% [markdown]
# **Giải đáp / SOLUTIONs.**
#
# Trình tự lý luận:
# - Đặt $L,A,H$ là 3 sự kiện tương ứng với việc chọn được hợp đồng BH là loại nào trong `"nhân thọ (life ins)"`, `"xe cộ (auto ins)"` và `"nhà cửa (home ins)"`. Theo các giả thiết, ta có (về số người)
#
# $$ \begin{array}{rll} \text{Theo (i) & (ii).} & |A| = 243, & |H| = 207 \\ \text{(iii) & (iv).} & |L \cap H| = 55, & |A\cap H| = 96 \\ \text{(v) & (vi).} & |A \cap L \cap R| = 32, & |A \cap L^c \cap H^c| - |L \cap A^c \cap H^c| = 76 \\ \text{(vii).} & |\text{co dung 1 goi BH}| = & |A \cap L^c \cap H^c| + |A^c \cap L \cap H^c| + |A^c \cap L^c \cap H| = 270 \end{array} $$
# - BT yêu cầu tính tổng số hợp đồng của những KH đã mua ít nhất một trong 3 loại BH trên, tức là $|A \cup L \cup H|$
# - Ta có
# $$ \begin{array}{crlrl} |L \cap H \cap A^c| &=& |L \cap H| - |L \cap H \cap A| &=& 55 - 32 = 23 \\ |A \cap H \cap L^c| &=& |A \cap H| - |A \cap H \cap L| &=& 96 -32 = 64 \end{array} $$
# kết hợp với $\text{(ii)}$; suy ra
#
# $$ \begin{array}{crlrl} |H \cap A^c \cap L^c| &=& |H \cap (A \cup L)^c| \\ &=& |H| - |H \cap (A \cup L)| \\  &=& |H| - |(H \cap L) \cup (H \cap A)| \\ &=& |H| - \left( |H \cap L| + |H \cap A| - |(H\cap A) \cap (H \cap L)| \right) \\ &=& |H| - \left( |H \cap L| + |(H \cap A) \cap L^c | \right) \\ &=& 207 - (55 + 64) \\ &=& 88 \end{array}$$

# %% [markdown]
# - Đặt $x = |L \cap A^c \cap H^c|$ và $y = |A \cap L^c \cap H^c|$; ta có hệ phương trình sau:
#
# $$ \left\lbrace \begin{array}{ccl} y - x &=&  |A \cap L^c \cap H^c| - |L \cap A^c \cap H^c| = 76 \\ x+y &=& 270 - |H \cap A^c \cap L^c| = 182 \end{array} \right. $$
# do đó $ \left\lbrace \begin{array}{ccl} x &=& 53 \\ y &=& 129 \end{array} \right. $
# - Vì vậy,
# $$ \begin{array}{ccl} |L \cap A \cap H^c| &=& |A| - |A \cap (L^c \cup H)| \\ &=& |A| - (|A \cap H| + |A \cap L^c| - |A \cap L^c \cap H| ) \\ &=& |A| - (|A \cap H | + |(A \cap L^c) \cap H^c|) \\ &=& 243 - (96 + 129) \\ &=& 18. \end{array} $$
# - Cuối cùng,
# $$ \begin{array}{crlrl} |H \cup A \cup L| &=& |\text{co dung 1 goi BH}| + |\text{co dung 2 goi BH}| + |\text{co ca 3 goi BH}| \\ &=& (53 + 129 + 88) + (18 + 64 + 23) + 32 \\ &=& 407. \end{array} $$
#
# ---------
#
# **Comment.**
# - Cách này tuy hợp về logic tập hợp nhưng quá phức tạp để áp dụng khi làm trắc nghiệm.
# - Do đó, nó sẽ đơn giản hơn nhiều nếu ta dùng biểu đồ Venn.

# %%
## hình minh họa

# %% [markdown]
# #### Question 244.
# A profile of the investments owned by an agent’s clients follows:
# - i) 228 own annuities.
# - ii) 220 own mutual funds.
# - iii) 98 own life insurance and mutual funds.
# - iv) 93 own annuities and mutual funds.
# - v) 16 own annuities, mutual funds, and life insurance.
# - vi) 45 more clients own only life insurance than own only annuities.
# - vii) 290 own only one type of investment (i.e., annuity, mutual fund, or life insurance).
#
# Calculate the agent’s total number of clients.

# %% [markdown]
# **Giải đáp / SOLUTIONs.**
#
# Để tránh giải toán rườm rà và phức tạp như bài trên, nhìn tóm tắt đề trực tiếp trong hình dưới đây:
# - Quy ước $A, M, L$ như viết tắt trong hình bên dưới
# - Theo các giả thiết (i)-(vii) ta có
#
# $\qquad \qquad \diamond$ Theo (i) & (ii) thì $|A| = 228$ và $|M| = 220$
#
# $\qquad \qquad \diamond$ Theo (iii) & (iv) thì $|L \cap M| = 98$ và $|A \cap M| = 93$
#
# $\qquad \qquad \diamond$ Theo (v) & (vi) thì $|A \cap L \cap M| = 16$ và
#
# $$|\text{Only} L| - |\text{Only} A| = |L \cap A^c \cap M^c| - |A \cap L^c \cap M^c| = 45$$
#
# $\qquad \qquad \diamond$ (vii), thì
#
# $$|\text{Only} L| + |\text{Only} A| + |\text{Only} M| = 290 \Leftrightarrow |L \cap A^c \cap M^c| + |A \cap L^c \cap M^c| + |M \cap L^c \cap A^c| = 290$$
#
# $\qquad \qquad \diamond$ Đặt $\left\lbrace \begin{array}{ccl} x &=& |\text{Only A}| = |A \cap L^c \cap M^c| \\ u &=& |\text{Only L}|= |L \cap A^c \cap M^c|  \\ y &=& |A\cap L \cap M^c| \end{array} \right.$;
#
# ta có được hình như dưới đây
#
# ---------------------------

# %%
## hình minh họa
# Out:
# Từ (vi) suy ra u - x = 45 hay u = x + 45
# Từ (iii) và (v) suy ra |L and M and (not A)| = |L and M| - |L and M and A| = 82.
# Từ (iv) và (v) suy ra |A and M and (not L)| = |A and M| - |L and M and A| = 77.
# Do đó: |Only M| = |M and (not A) and (not L)| = 280 - 77 - 16 - 82  = 45.

# %% [markdown]
# - Sau cùng, ta sẽ tìm $x, y$ thông qua hệ phương trình sau (từ `(vii)` & `(i)`)
#
# $$ \left\lbrace \begin{array}{cclrl} 290 &=& |\text{Only} L| + |\text{Only} A| + |\text{Only} M| = (x+45) + x + 45 &=& 2x + 90 \\ 228 &=& |A| = x+y+16+77 &=& x+y + 93  \end{array} \right. $$
#
# suy ra $\left\lbrace \begin{array}{ccl} x &=& 100 \\ y &=& 35 \end{array} \right. $ và do đó, tổng số KH sẽ là
#
# $$ | L \cup A \cup M | = x+y+(x+45)+82+45+77+16 = 500. $$
#
# -------------------

# %% [markdown]
# #### Question 245.
# An **insurance policy pays** 100 per day for up to three days of hospitalization and 50 per day for each day of hospitalization thereafter.
#
# The **number of days of hospitalization**, $X$, is a discrete random variable with probability function
#
# $$ P[X=k]= \left\lbrace \begin{array}{cl} \dfrac{6-k}{15}, & k = 1,2,3,4,5. \\ 0, & \text{otherwise} \end{array} \right. $$
#
# Calculate the expected payment for hospitalization under this policy.

# %% [markdown]
# **Giải đáp / SOLUTIONs.**
#
# Trình tự lý luận:
# - Đầu tiên, dễ dàng kiểm chứng $\displaystyle \sum_{k=1}^{\infty} P[X=k] = \sum_{k=1}^5 \dfrac{6 - k}{15} = 1.$
# - Đặt $Y=g(X)$ là chi phí trả tiền viện phí theo ngày; theo đó
#
# $$ g(x) = \left\lbrace \begin{array}{cll} 100x, & x = 1,2,3, & \text{vien.phi trong 3 ngay dau tiên: 100 per day} \\ 50x , & x = 4,5,\ldots & \text{vien phi trong nhung ngay ke tiep: 50 per day} \end{array} \right. $$
# - BT yêu cầu tính kỳ vọng số tiền chi trả, tức là
#
# $$ \mathbb{E}Y = \displaystyle \sum_{k=0}^5 g(k) \cdot P[X = k] = 100 \left( \dfrac{5}{15} \right) + 100 \left( \dfrac{4}{15} \right) + 100 \left( \dfrac{3}{15} \right) + 50 \left( \dfrac{2}{15} \right) + 50 \left( \dfrac{1}{15} \right) = 220. $$

# %% [markdown]
# #### Question 246.
# An actuary compiles the following information from a portfolio of $1000$ homeowners insurance policies:
# - i) 130 policies insure three-bedroom homes.
# - ii) 280 policies insure one-story homes.
# - iii) 150 policies insure two-bath homes.
# - iv) 30 policies insure three-bedroom, two-bath homes.
# - v) 50 policies insure one-story, two-bath homes.
# - vi) 40 policies insure three-bedroom, one-story homes.
# - vii) 10 policies insure three-bedroom, one-story, two-bath homes.
#
# Calculate the number of homeowners policies in the portfolio that insure **neither onestory nor two-bath nor three-bedroom homes**.

# %% [markdown]
# **Giải đáp / SOLUTIONs.**
#
# Trình tự lý luận:
# - Đặt $E, T, A$ lần lượt tương ứng với các hợp đồng nhà BH loại `3-bedroom`; `1-story` và `2-bath`
# - Theo các giả thiết (i)-(vii) ta có
#
# $\qquad \qquad \diamond$ Theo (i) - (iii) thì $|E| = 130$ và $|T| = 280$ và $|A| = 150$
#
# $\qquad \qquad \diamond$ Theo (iv) - (vi) thì
#
# $$ |E \cap A| = 30, \qquad |T \cap A| = 50, \qquad |E \cap T| = 40. $$
#
# $\qquad \qquad \diamond$ Theo (vii) thì $|E \cap T \cap A| = 10.$

# %%
## hình minh họa

# %% [markdown]
# - Xem hình trên, suy ra
#
# $$ |A \cup E \cup T| = |A|+|E|+|T| - (|A \cap E| + |A \cap T| + |T \cap E|) + |A \cap T \cap E| = 450. $$
# - Vì BT yêu cầu tính số người không chọn danh mục nào trong $A, B, C$ trên tổng số 1000 KH đã khảo sát, do đó
#
# $$ |(A \cup E \cup T)^c| = 1000 - |A \cup E \cup T| = 550.$$

# %% [markdown]
# #### Question 247.
# Each week, a subcommittee of four individuals is formed from among the members of a
# committee comprising seven individuals. Two subcommittee members are then assigned
# to lead the subcommittee, one as chair and the other as secretary.
#
# Calculate the maximum number of consecutive weeks that can elapse without having the
# subcommittee contain four individuals who have previously served together with the
# same subcommittee chair.

# %% [markdown]
# **Giải đáp / SOLUTIONs.**
#
# Đề bài cho biết; cứ hàng tuần,
# - Một tiểu ban tất cả $7$ người được chọn vào một Hội đồng (committee) gồm 4 người.
# - Tương ứng 4 người được chọn sẽ có : 1 Chủ tịch (chairman), 1 thư ký (secretary) và 2 lãnh đạo tiểu ban (sub-committee)
#
# BT yêu cầu tính **số tối đa các tuần liên tiếp** mà 4 thành viên trong tiểu ban được chọn vào Hội đồng và đã từng đảm nhận chức chủ tịch. Do đó, ta sẽ lập luận như sau:
# - Để chọn được $4$ trong $7$ người vào một Hội Đồng; ta có $C_7^4 = \dfrac{7!}{4! (7-4)!} = 35$ cách.
# - Với mỗi người trong 4 người trong Hội Đồng vào vị trí chủ tịch, ta có $C_4^1 = 4$ cách chọn.
# - Do đó, $C_7^4 C_4^1 = 140$ là số cách khác nhau để thành lập một Hội đồng gồm 4 thành viên và trong số họ có một chủ tịch và do đó; đây là số lần (số tuần liên tiếp) tối đa mà việc thành lập Hội Đồng không có sự lặp lại.

# %% [markdown]
# #### Question 248.
# - **Bowl I** contains eight red balls and six blue balls. **Bowl II** is empty.
# - Four balls are selected at random, without replacement, and transferred from bowl I to bowl II.
# - One ball is then selected at random from bowl II.
#
# Calculate the conditional probability that two red balls and two blue balls were transferred from bowl I to bowl II, given that the ball selected from bowl II is blue.

# %% [markdown]
# **Giải đáp / SOLUTIONs.**
#
# Trình tự lý luận:
# - Đặt $X, Y$ lần lượt là sự kiện lấy được bát I (`Bowl I`) hay bát II (`Bowl II`); và $R, B$ lần lượt là màu của bi trong bát
# - Theo `(i)`
#
# $$ X = \lbrace 8 R, 6B \rbrace, \qquad Y = \lbrace 0 R, 0B \rbrace $$
# - Theo `(ii)-(iii)`, rút 4 bi không hoàn lại từ $X$ bỏ sang $Y$; rồi lại lấy ngẫu nhiên một viên từ $Y$
# - BT yêu cầu tính XS có điều kiện: **chọn được 2 bi đỏ (2R) và2 xanh được chuyển từ X sang Y biết rằng bi chọn được từ Y là xanh (B)**, tức là
#
# $$ P\left[ 2R, 2B \text{ transf from X to Y} | \text{B drawn from Y} \right] = \dfrac{P[2R, 2B \text{ (transf from X to Y)} \cap \text{(B drawn from Y)}]}{P[\text{B drawn from Y}]} $$
# ta có
# $$ \begin{array}{ccl} P[2R, 2B \text{ (transf from X to Y)} \cap \text{(B drawn from Y)}] &=& \dfrac{|\text{select 2R, 2B from X = (8R, 6B)}|\cdot |\text{select B from Y = (2R, 2B)}| }{|\text{select 4 balls from 14 balls of X}|} \\ &=& \dfrac{|\text{select (2R from 8R) and (2B from 6B)}|\cdot |\text{select B from Y = (2R, 2B)}| }{|\text{select 4 balls from 14 balls of X}|} \\ &=& \dfrac{\left( C_8^2 C_6^2 \right) \cdot \left( \dfrac{2}{2+2} \right)}{C_{14}^4} \\ &=& \dfrac{840}{4004}. \end{array} $$

# %% [markdown]
# và
# $$ \begin{array}{ccl} P[\text{B drawn from Y}] &=& \dfrac{|\text{select B from Y which at least 1 blue ball}|}{|\text{select 4 balls from 14 balls of X}|} \\ &=& \dfrac{|\text{select B from 4 cases of Y (0R, 4B), (1R, 3B), (2R, 2B) and (3R, 1B)}|}{|\text{select 4 balls from 14 balls of X}|} \\ &=& \displaystyle \sum_{k=1}^4 \dfrac{|\text{select [k.B and (4 - k)R] from X}| \cdot |\text{select B from [k.B and (4 - k)R]}|}{|\text{select 4 balls from 14 balls of X}|} \\ &=& \displaystyle \sum_{k=1}^4 \dfrac{\left( C_8^{4-k} C_6^k \right) \cdot \left( \dfrac{k}{4} \right) }{C_{14}^4} \\ &=& \dfrac{\left( C_8^{3} C_6^1 \right) \cdot \left( \dfrac{1}{4} \right) + \left( C_8^{2} C_6^2 \right) \cdot \left( \dfrac{2}{4} \right) + \left( C_8^{1} C_6^3 \right) \cdot \left( \dfrac{3}{4} \right) + \left( C_8^{0} C_6^4 \right) \cdot \left( \dfrac{4}{4} \right)}{C_{14}^4} \\ &=& \dfrac{1716}{4004} \end{array} $$
#
# suy ra
#
# $$ P\left[ 2R, 2B \text{ transf from X to Y} | \text{B drawn from Y} \right] = \dfrac{\frac{840}{4004}}{\frac{1716}{4004}} = \dfrac{840}{1716} = 0.49 $$

# %% [markdown]
# #### Question 249.
# An actuary has done an analysis of all policies that cover two cars. 70% of the policies
# are of type A for both cars, and 30% of the policies are of type B for both cars. The
# number of claims on different cars across all policies are mutually independent. The
# distributions of the number of claims on a car are given in the following table.
#
# | Number of Claims | Type A | Type B |
# |:-:|-|-|
# | $0$| $40\%$| $25\%$|
# |$1$| $30\%$| $25\%$|
# |$2$| $20\%$| $25\%$|
# |$3$| $10\%$| $25\%$|
#
# Four policies are selected at random.
# Calculate the probability that exactly one of the four policies has the same number of
# claims on both covered cars.

# %% [markdown]
# **Giải đáp / SOLUTIONs.**
#
# Trình tự lý luận:
# - Đặt $A, B$ lần lượt là sự kiện mà hợp đồng đó đến từ chính sách loại $A$ hay $B$; theo đó $$P[A] = 0.7, \qquad P[B] = 0.3$$
# - BT yêu cầu tính XS **để có đúng một trong $4$ chính sách có số yêu cầu như nhau trên cả hai ô tô được bảo hiểm**.
# - Đặt $\theta_A, \theta_B$ lần lượt là XS để chính sách loại $A, B$ có 2 lượng yêu cầu bằng nhau. Cụ thể
#
# $\qquad \diamond$ $\theta_A$ là XS để chính sách loại $A$ có 2 lượng yêu cầu $A_1, A_2$ bằng nhau, do đó
#
# $$ \theta_A = \displaystyle \sum_{k=0}^3 P[A_1 = k, A_2 = k] = \sum_{k=0}^3 (P[A = k])^2 = (0.4)^2 + (0.3)^2 + (0.2)^2 + (0.1)^2 = 0.30 $$
#
# $\qquad \diamond$ Tương tự $\theta_B$ là XS để chính sách loại $B$ có 2 lượng yêu cầu $B_1, B_2$ bằng nhau,
#
# $$ \theta_B = \displaystyle \sum_{k=0}^3 P[B_1 = k, B_2 = k] = \sum_{k=0}^3 (P[B = k])^2 = 4 \cdot (0.25)^2 = 0.25. $$
# - Do đó, XS để chọn ngẫu nhiên một chính sách mà lượng yêu cầu nhận được bằng nhau sẽ bằng
#
# $$ \theta = \theta_A \cdot P[A] + \theta_B \cdot p[B] = 0.285. $$
# - Như vậy, với $4$ chính sách được chọn, nó sẽ tuân theo phân phối nhị thức $\mathcal{B}(4, \theta)$, do đó XS cần tìm chính là
#
# $$ P[\mathcal{B}(4, \theta) = 1] = C_4^1 \theta (1 - \theta)^3 = 0.417. $$

# %% [markdown]
# #### Question 250.
# A company sells two types of life insurance policies ($P$ and $Q$) and one type of health
# insurance policy. A survey of potential customers revealed the following:
# - i) No survey participant wanted to purchase both life policies.
# - ii) Twice as many survey participants wanted to purchase life policy $P$ as life policy $Q$.
# - iii) $45\%$ of survey participants wanted to purchase the health policy.
# - iv) $18\%$ of survey participants wanted to purchase only the health policy.
# - v) The event that a survey participant wanted to purchase the health policy was independent of the event that a survey participant wanted to purchase a life policy.
#
# Calculate the probability that a randomly selected survey participant wanted to purchase exactly one policy.

# %% [markdown]
# **Giải đáp / SOLUTIONs.**
#
# Trình tự lý luận:
# - Đặt $W, Q, H$ lần lượt tương ứng với các gói BH nhân thọ (2 loại) $P,Q$ và BH sức khỏe $H$.
# - Theo các giả thiết,
#
# $\qquad \diamond$ (i) $W \cap Q = \emptyset$ hay $|W \cap Q| = 0 $
#
# $\qquad \diamond$ (ii) $P[W] = 2P[Q]$
#
# $\qquad \diamond$ (iii) $P[H] = 0.45$
#
# $\qquad \diamond$ (iv) $P[\text{only } H] = 0.18$ hay $P[H \cap W^c \cap Q^c] = 0.18$
#
# $\qquad \diamond$ (v) Sự kiện người tham gia khảo sát muốn mua BH sức khỏe $H$ độc lập với sự kiện người tham gia khảo sát muốn mua chính sách nhân thọ $Q \cup W$; điều này có nghĩa là
# $$ P[(Q \cup W) \cap H] = P[H] \cdot P[Q \cup W] $$
# kết hợp với (i) và (iii), ta có
#
# $$ P[Q \cap H] + P[W \cap H] = (0.45) \cdot P[Q \cup W] $$
#
# - Do đó, ta đặt $\left\lbrace \begin{array}{ccl} x &=& P[\text{only } W] \\ y &=& P[W \cap H^c] \\ z &=& P[Q \cap H^c] \\ t &=& P[\text{only } Q] \end{array} \right.$, khi đó ta có kq như hình dưới đây

# %%
## hình minh họa

# %% [markdown]
# - (ii) suy ra $x + y = 2(z + t)$
# - (iii) và (iv) suy ra $y + 0.18 +z = 0.45$ và $y + z = 0.27$
# - (v) suy ra $y + z = (x+y+z+t)0.45$
# - BT yêu cầu tính
# $$ P[\text{Exactly one policy}] = P[\text{Only }W] + P[\text{Only }H] + P[\text{Only }Q] = x + 0.18 + t $$
#
# do đó ta cần tìm $x+t$ theo 3 phương trình trong giả thiết trên, ta có
#
# $$ \begin{array}{rccl} & y + z &=& (x+y+z+t)0.45 \\ \Rightarrow & 0.27 &=& 0.45(x+t + 0.27) \\ \Rightarrow & x + t &=& 0.33 \end{array} $$
# Vậy
# $$ P[\text{Exactly one policy}] = x + 0.18 + t $$
