# %%
import numpy as np
import pandas as pd
import pyodbc
import sqlalchemy
import sqlite3

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
from subprocess import check_output

conn = sqlite3.connect('/kaggle/input/ipldatabase/database.sqlite')
conn_2 = sqlite3.connect('/kaggle/input/sf-salaries/database.sqlite')
exectue = conn.cursor()
exectue_2 = conn_2.cursor()

# %% [markdown]
# ### Viewing full database

# %%
SQL_season = pd.read_sql(
    """
    SELECT * 
    FROM Season
    """, con = conn)
SQL_season
# Out:
#    Season_Id  Man_of_the_Series  Orange_Cap  Purple_Cap  Season_Year
# 0          1                 32         100         102         2008
# 1          2                 53          18          61         2009
# 2          3                133         133         131         2010
# 3          4                162         162         194         2011
# 4          5                315         162         190         2012
# 5          6                 32          19          71         2013
# 6          7                305          46         364         2014
# 7          8                334         187          71         2015
# 8          9                  8           8         299         2016

# %%
SQL_match = pd.read_sql(
    """
    SELECT * 
    FROM Match
    """, con = conn)
print(SQL_match.shape)
SQL_match.head(10)
# Out:
# (577, 13)
#    Match_Id  Team_1  Team_2           Match_Date  Season_Id  Venue_Id  \
# 0    335987       2       1  2008-04-18 00:00:00          1         1
# 1    335988       4       3  2008-04-19 00:00:00          1         2
# 2    335989       6       5  2008-04-19 00:00:00          1         3
# 3    335990       7       2  2008-04-20 00:00:00          1         4
# 4    335991       1       8  2008-04-20 00:00:00          1         5
# 5    335992       5       4  2008-04-21 00:00:00          1         6
# 6    335993       8       6  2008-04-22 00:00:00          1         7
# 7    335994       3       7  2008-04-23 00:00:00          1         8
# 8    335995       8       5  2008-04-24 00:00:00          1         7
# 9    335996       4       7  2008-04-25 00:00:00          1         2
#
#    Toss_Winner  Toss_Decide  Win_Type  Win_Margin  Outcome_type  Match_Winner  \
# 0            2            1         1       140.0             1           1.0
# 1            3            2         1        33.0             1           3.0
# 2            5            2         2         9.0             1           6.0
# 3            7            2         2         5.0             1           2.0
# 4            8            2         2         5.0             1           1.0
# 5            4            2         2         6.0             1           5.0
# 6            8            2         2         9.0             1           6.0
# 7            7            1         1         6.0             1           3.0
# 8            5            1         2         3.0             1           5.0
# 9            7            1         1        66.0             1           4.0
#
#    Man_of_the_Match
# 0               2.0
# 1              19.0
# 2              90.0
# 3              11.0
# 4               4.0
# 5              32.0
# 6              41.0
# 7              18.0
# 8              31.0
# 9              26.0

# %%
SQL_salaries = pd.read_sql(
    """
    SELECT * 
    FROM Salaries
    """, con = conn_2)
print(SQL_salaries.shape)
SQL_salaries.head(10)
# Out:
# (148654, 13)
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#   BasePay OvertimePay OtherPay Benefits TotalPay TotalPayBenefits  Year Notes  \
# 0  167411        null   400184     null   567595           567595  2011  null
# 1  155966      245132   137811     null   538909           538909  2011  null
# 2  212739      106088  16452.6     null   335280           335280  2011  null
# 3   77916     56120.7   198307     null   332344           332344  2011  null
# 4  134402        9737   182235     null   326373           326373  2011  null
# 5  118602        8601   189083     null   316286           316286  2011  null
# 6   92492     89062.9   134426     null   315981           315981  2011  null
# 7  256577        null  51322.5     null   307899           307899  2011  null
# 8  176933     86362.7  40132.2     null   303428           303428  2011  null
# 9  285262        null  17115.7     null   302378           302378  2011  null
#
#           Agency Status
# 0  San Francisco   null
# 1  San Francisco   null
# 2  San Francisco   null
# 3  San Francisco   null
# 4  San Francisco   null
# 5  San Francisco   null
# 6  San Francisco   null
# 7  San Francisco   null
# 8  San Francisco   null
# 9  San Francisco   null

# %%
df = SQL_salaries['Status']
len(df[df == 'PT'])
# Out:
# 15785

# %% [markdown]
# ### PRACTICES
#
# In SQL, the **WHERE** keyword allows you to filter based on both text and numeric values in a table. There are a few different comparison operators you can use:
#
#          = "equal"
#          != or <> "not equal"
#          < "less than"
#          > "greater than"
#          <= "less than or equal to"
#          >= "greater than or equal to"
#
# ## 1. Simple filtering : on numeric & text
#
# ### 1.1. Simple filtering of numeric values
#
# For example, the following **`query`** selects all details for `season` with the `man_of_series` over one hundred:
#
#         SELECT * FROM Season WHERE Man_of_the_series > 100

# %%
SQL_season = pd.read_sql(
    """
    SELECT * FROM Season
    WHERE Man_of_the_Series > 100
    """, con = conn)
SQL_season
# Out:
#    Season_Id  Man_of_the_Series  Orange_Cap  Purple_Cap  Season_Year
# 0          3                133         133         131         2010
# 1          4                162         162         194         2011
# 2          5                315         162         190         2012
# 3          7                305          46         364         2014
# 4          8                334         187          71         2015

# %% [markdown]
# ### 1.2. Simple filtering of text
#
# For example, this `query` gets the `teams` of all `seasons` which were `match-days` is `12 th, April 2015`.
#
# **Remember that we must use "ISO date_format": `yyyy-mm-dd` + `hh:mm:ss`**

# %%
SQL_season = pd.read_sql(
    """
    SELECT Team_1, Team_2, Match_date
    FROM Match
    WHERE Match_date = '2015-04-12 00:00:00';
    """, con = conn)
SQL_season
# Out:
#    Team_1  Team_2           Match_Date
# 0       6       5  2015-04-12 00:00:00
# 1       7       4  2015-04-12 00:00:00

# %% [markdown]
# ### 1.3. Extractin specific `year`, `month` or `date` only
#
# For examlple, we want to explore the information of `team_1` and `team_2` in the `date of match_date = 18` from database `Match`

# %%
SQL_season = pd.read_sql(
    """
    SELECT Team_1, Team_2, Match_Date
    FROM Match
    WHERE strftime('%d', Match_Date) = '18'
    """, con = conn)
SQL_season
# Out:
#     Team_1  Team_2           Match_Date
# 0        2       1  2008-04-18 00:00:00
# 1        8       7  2008-05-18 00:00:00
# 2        1       3  2008-05-18 00:00:00
# 3        3       7  2009-04-18 00:00:00
# 4        2       5  2009-04-18 00:00:00
# 5        3       1  2009-05-18 00:00:00
# 6        2       5  2010-03-18 00:00:00
# 7        4       3  2010-04-18 00:00:00
# 8        6       8  2010-04-18 00:00:00
# 9        9       3  2011-04-18 00:00:00
# 10       3       9  2011-05-18 00:00:00
# 11       4       1  2012-04-18 00:00:00
# 12       8       5  2012-05-18 00:00:00
# 13       6       3  2013-04-18 00:00:00
# 14       4       7  2013-05-18 00:00:00
# 15       2       3  2013-05-18 00:00:00
# 16       3       4  2014-04-18 00:00:00
# 17      11       5  2014-04-18 00:00:00
# 18       3       2  2014-05-18 00:00:00
# 19      11       1  2014-05-18 00:00:00
# 20      11       6  2015-04-18 00:00:00
# 21       4       1  2015-04-18 00:00:00
# 22      11       7  2016-04-18 00:00:00
# 23       2       4  2016-05-18 00:00:00

# %% [markdown]
# ## 2. WHERE AND & WHERE OR
#
# ### 2.1. WHERE AND
#
# Often, you'll want to select data based on multiple conditions. You can build up your WHERE queries by combining multiple conditions with the AND keyword.
#
# For example,

# %%
SQL_season = pd.read_sql(
    """
    SELECT * FROM Season
    WHERE Man_of_the_Series > 150
    AND Purple_cap > 100
    AND Orange_cap > 50
    """, con = conn)
SQL_season
# Out:
#    Season_Id  Man_of_the_Series  Orange_Cap  Purple_Cap  Season_Year
# 0          4                162         162         194         2011
# 1          5                315         162         190         2012

# %% [markdown]
# gives us the informations of `seasons`-database which satisfied
#
#                                 Man_of_the_Series > 150
#                                 Purple_cap > 10
#                                 Orange_cap > 50
#
# Another example; using **AND** to extract information of year; month and the man_of_the_match in database `Match`

# %%
SQL_season = pd.read_sql(
    """
    SELECT Team_1, 
           Team_2, 
           strftime('%d / %m/ %Y', Match_Date) AS Match_Date_new_format, 
           Man_of_the_match
    FROM Match
    WHERE strftime('%Y', Match_Date) = '2009'
    AND strftime('%m', Match_Date) = '05'
    AND Man_of_the_match > 100
    """, con = conn)
SQL_season
# Out:
#    Team_1  Team_2 Match_Date_new_format  Man_of_the_Match
# 0       1       7         01 / 05/ 2009               154
# 1       3       6         02 / 05/ 2009               186
# 2       2       5         07 / 05/ 2009               196
# 3       2       7         10 / 05/ 2009               154
# 4       6       1         10 / 05/ 2009               136
# 5       8       5         11 / 05/ 2009               147
# 6       6       5         17 / 05/ 2009               110
# 7       3       1         18 / 05/ 2009               104
# 8       3       4         20 / 05/ 2009               121
# 9       2       8         24 / 05/ 2009               124

# %% [markdown]
# In this `query`; we has used the keyword **`Alias`(AS)**  in the statement`"strftime('%d / %m/ %Y', Match_Date) AS Match_Date_new_format"` to `rename` the `new_format of date_time` as `dd/mm/yyyy`.
#
# ### 2.2.WHERE OR

# %%
SQL_match = pd.read_sql(
    """
    SELECT Team_1, Team_2, Toss_Winner, Match_date, Toss_Decide, Man_of_the_Match
    FROM Match
    WHERE Team_1 = Toss_Winner
    OR Man_of_the_Match >= 300
    """, con = conn)
SQL_match
# Out:
#      Team_1  Team_2  Toss_Winner           Match_Date  Toss_Decide  \
# 0         2       1            2  2008-04-18 00:00:00            1
# 1         7       2            7  2008-04-20 00:00:00            2
# 2         8       6            8  2008-04-22 00:00:00            2
# 3         1       7            1  2008-04-29 00:00:00            2
# 4         5       1            5  2008-05-01 00:00:00            2
# ..      ...     ...          ...                  ...          ...
# 318      12       6           12  2016-05-17 00:00:00            1
# 319      13       1           13  2016-05-19 00:00:00            1
# 320       6      11            6  2016-05-20 00:00:00            1
# 321      13       7           13  2016-05-21 00:00:00            1
# 322       2      11           11  2016-05-29 00:00:00            2
#
#      Man_of_the_Match
# 0                 2.0
# 1                11.0
# 2                41.0
# 3                44.0
# 4               101.0
# ..                ...
# 318             106.0
# 319             147.0
# 320             339.0
# 321              21.0
# 322             385.0
#
# [323 rows x 6 columns]

# %% [markdown]
# ### PLAYING WITH WHERE AND(... OR ...)

# %%
SQL_match = pd.read_sql(
    """
    SELECT Team_1, Team_2,
           strftime('%d / %m/ %Y', Match_Date) AS Match_Date_new_format,
           Toss_Winner, Toss_Decide, Man_of_the_Match
    FROM Match
    WHERE (strftime('%d', Match_Date) = '18' OR strftime('%d', Match_Date) = '29')
    AND(Man_of_the_Match >= 350 OR Man_of_the_Match <= 50)
    OR(Toss_winner = 5 AND Toss_Decide = 1)
    """, con = conn)
SQL_match
# Out:
#     Team_1  Team_2 Match_Date_new_format  Toss_Winner  Toss_Decide  \
# 0        2       1         18 / 04/ 2008            2            1
# 1        8       5         24 / 04/ 2008            5            1
# 2        2       5         26 / 04/ 2008            5            1
# 3        1       7         29 / 04/ 2008            1            2
# 4        5       8         09 / 05/ 2008            5            1
# 5        5       6         11 / 05/ 2008            5            1
# 6        4       5         28 / 05/ 2008            5            1
# 7        1       5         20 / 05/ 2008            5            1
# 8        5       7         26 / 05/ 2008            5            1
# 9        3       5         01 / 06/ 2008            5            1
# 10       2       5         18 / 04/ 2009            2            2
# 11       2       1         29 / 04/ 2009            1            2
# 12       4       7         29 / 04/ 2009            4            2
# 13       3       5         30 / 04/ 2009            5            1
# 14       2       5         07 / 05/ 2009            5            1
# 15       2       5         18 / 03/ 2010            2            1
# 16       5       7         11 / 04/ 2010            5            1
# 17       4       3         18 / 04/ 2010            3            1
# 18       8       5         09 / 04/ 2011            5            1
# 19       9       3         18 / 04/ 2011            9            1
# 20       4       5         21 / 04/ 2011            5            1
# 21       5       9         24 / 04/ 2011            5            1
# 22       5       7         29 / 04/ 2011            5            1
# 23       2      10         29 / 04/ 2011           10            1
# 24       5      10         01 / 05/ 2011            5            1
# 25       5       3         09 / 05/ 2011            5            1
# 26       7       5         11 / 04/ 2012            5            1
# 27       4       1         18 / 04/ 2012            4            2
# 28       5       2         23 / 04/ 2012            5            1
# 29       6       5         29 / 04/ 2012            6            2
# 30       5       4         14 / 04/ 2013            5            1
# 31       6       3         18 / 04/ 2013            3            2
# 32       5       2         29 / 04/ 2013            5            1
# 33       4       5         09 / 05/ 2013            5            1
# 34       5       3         12 / 05/ 2013            5            1
# 35       7       5         15 / 05/ 2013            5            1
# 36       2       3         18 / 05/ 2013            3            1
# 37      11       5         18 / 04/ 2014            5            1
# 38       5       3         23 / 04/ 2014            5            1
# 39       5       2         26 / 04/ 2014            5            1
# 40       6       5         03 / 05/ 2014            5            1
# 41       5      11         08 / 05/ 2014            5            1
# 42       4       5         23 / 05/ 2014            5            1
# 43       6       5         12 / 04/ 2015            5            1
# 44      11       5         16 / 04/ 2015            5            1
# 45       2       5         29 / 04/ 2015            5            1
# 46       7       5         01 / 05/ 2015            5            1
# 47       5      11         07 / 05/ 2015            5            1
# 48       2       4         18 / 05/ 2016            4            1
# 49       2      11         29 / 05/ 2016           11            2
#
#     Man_of_the_Match
# 0                2.0
# 1               31.0
# 2               32.0
# 3               44.0
# 4               31.0
# 5               32.0
# 6              100.0
# 7               31.0
# 8              102.0
# 9               31.0
# 10               6.0
# 11              11.0
# 12              26.0
# 13              21.0
# 14             196.0
# 15               9.0
# 16             133.0
# 17              20.0
# 18              39.0
# 19               2.0
# 20             100.0
# 21              38.0
# 22             192.0
# 23               8.0
# 24              52.0
# 25             185.0
# 26             221.0
# 27              40.0
# 28             110.0
# 29              41.0
# 30             310.0
# 31              19.0
# 32             351.0
# 33             309.0
# 34              32.0
# 35             207.0
# 36               8.0
# 37              85.0
# 38              35.0
# 39             370.0
# 40             339.0
# 41             299.0
# 42             100.0
# 43             394.0
# 44              85.0
# 45               NaN
# 46             208.0
# 47             216.0
# 48               8.0
# 49             385.0

# %% [markdown]
# ## 3. BETWEEN & WHERE IN
# ### 3.1. BETWEEN.
#
# Similar to the **WHERE** clause, the **BETWEEN** clause can be used with multiple **AND** and **OR** operators, so we can build up your queries and make them even more powerful!
#
# For example, suppose we have a table called `Salaries`. We can get the names of all employees between the time of 2011 and 2014; conditional on the BasePay between in 290000 and 350000 from the United States.

# %%
SQL_salaries = pd.read_sql(
    """
    SELECT * 
    FROM Salaries
    WHERE BasePay BETWEEN 290000 AND 350000
    AND Year BETWEEN 2010 AND 2014
    """, con = conn_2)
SQL_salaries.head(10)
# Out:
#       Id          EmployeeName                      JobTitle    BasePay  \
# 0     13     EDWARD HARRINGTON   EXECUTIVE CONTRACT EMPLOYEE  294580.02
# 1  36161          Gregory Suhr               Chief of Police  302578.00
# 2  36163    Joanne Hayes-White        Chief, Fire Department  296943.01
# 3  36166        Edward Reiskin    Gen Mgr, Public Trnsp Dept  294000.17
# 4  72926        Gregory P Suhr               Chief of Police  319275.01
# 5  72927  Joanne M Hayes-White        Chief, Fire Department  313686.01
# 6  72930         Robert L Shaw  Dep Dir for Investments, Ret  315572.01
# 7  72932     Harlan L Kelly-Jr   Executive Contract Employee  313312.52
# 8  72933         John L Martin                   Dept Head V  311758.96
# 9  72934      Edward D Reiskin    Gen Mgr, Public Trnsp Dept  305307.89
#
#   OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year Notes  \
# 0        null     null     null  294580.02         294580.02  2011  null
# 1        null  18974.1  69810.2  321552.11         391362.30  2012  null
# 2        null  17816.6  72047.9  314759.60         386807.48  2012  null
# 3        null     null  82001.9  294000.17         376002.11  2012  null
# 4        null  20007.1  86533.2  339282.07         425815.28  2013  null
# 5        null    23236  85431.4  336922.01         422353.40  2013  null
# 6        null     null  82849.7  315572.01         398421.67  2013  null
# 7        null     null  82319.5  313312.52         395632.03  2013  null
# 8        null  1098.64  82476.9  312857.60         395334.45  2013  null
# 9        null     null  80860.6  305307.89         386168.49  2013  null
#
#           Agency Status
# 0  San Francisco   null
# 1  San Francisco   null
# 2  San Francisco   null
# 3  San Francisco   null
# 4  San Francisco   null
# 5  San Francisco   null
# 6  San Francisco   null
# 7  San Francisco   null
# 8  San Francisco   null
# 9  San Francisco   null

# %% [markdown]
# Now, using **BETWEEN** with **AND** on the `Salaries` data to get the :`Id, JobTitle, EmployeeName, Basepay & Totalpay` of the **occupation:** `'PHARMACY TECHNICIAN' or 'Transit Operator'` satisfied the **basepay** in [59000, 65000] while **Totalpay** exceeded 80000.

# %%
SQL_salaries = pd.read_sql(
    """
        SELECT Id, JobTitle, Year, EmployeeName, BasePay, TotalPay
        FROM Salaries
        WHERE BasePay BETWEEN 59000 AND 60000
        AND TotalPay >= 80000
        AND (JobTitle = 'PHARMACY TECHNICIAN' OR JobTitle = 'Transit Operator')
    """, con = conn_2)
SQL_salaries
# Out:
#         Id          JobTitle  Year         EmployeeName   BasePay  TotalPay
# 0    48570  Transit Operator  2012        Gregory Johns  59558.70  88046.14
# 1    48759  Transit Operator  2012      Santos Bellorin  59665.25  88584.79
# 2    49816  Transit Operator  2012            Weilin Yu  59861.42  83816.39
# 3    50154  Transit Operator  2012   Gretchen Alexander  59885.45  82567.73
# 4    50155  Transit Operator  2012       Anderson Cheng  59255.60  82965.09
# 5    50508  Transit Operator  2012         Michael Wood  59996.15  80352.99
# 6    50574  Transit Operator  2012       Arthur Johnson  59187.03  81044.65
# 7    50686  Transit Operator  2012  Flor De Mari Segura  59798.96  80823.62
# 8    50996  Transit Operator  2012        Ronald Turner  59065.70  80030.70
# 9    87168  Transit Operator  2013      Terry L Sampson  59971.06  88411.71
# 10   88155  Transit Operator  2013          John T Tran  59739.33  84490.81
# 11  122000  Transit Operator  2014              Lan Lau  59804.10  99891.09
# 12  123817  Transit Operator  2014       Daymian Turner  59249.64  91054.14
# 13  124547  Transit Operator  2014    Michael S Whitten  59485.15  87913.03
# 14  124717  Transit Operator  2014      Gregory L Kelly  59353.83  88080.83
# 15  125094  Transit Operator  2014         Jefry M Liem  59462.90  84680.35
# 16  125097  Transit Operator  2014      Felix J Lagasca  59663.89  84780.95
# 17  125636  Transit Operator  2014        Masis Azizian  59869.80  82832.32
# 18  125852  Transit Operator  2014    Johnny Sanh Hoang  59263.98  82143.41
# 19  125967  Transit Operator  2014   Blanca R Contreras  59060.91  82174.69
# 20  126268  Transit Operator  2014        Anthony Sonza  59420.61  82256.12
# 21  126281  Transit Operator  2014      George J Murray  59440.49  81279.83

# %% [markdown]
# ### 3.2. WHERE IN.
# As you've seen, **WHERE** is very useful for `filtering` results. However, if you want to filter based on many conditions, **WHERE** can get unwieldy. For example:

# %%
SQL_salaries = pd.read_sql(
    """
        SELECT Id, JobTitle, Year, EmployeeName, BasePay, TotalPay
        FROM Salaries
        WHERE JobTitle IN ('Chief of Police', 'Chief, Fire Department', 'ASSISTANT DEPUTY CHIEF II', 'BATTALION CHIEF, (FIRE DEPARTMENT)')
        AND BasePay > 117000
        AND TotalPay > 216000
    """, con = conn_2)
SQL_salaries
# Out:
#         Id                            JobTitle  Year          EmployeeName  \
# 0        6           ASSISTANT DEPUTY CHIEF II  2011        DAVID SULLIVAN
# 1        9  BATTALION CHIEF, (FIRE DEPARTMENT)  2011        MICHAEL MORRIS
# 2       15  BATTALION CHIEF, (FIRE DEPARTMENT)  2011        DAVID FRANKLIN
# 3       19  BATTALION CHIEF, (FIRE DEPARTMENT)  2011            MARTY ROSS
# 4       24  BATTALION CHIEF, (FIRE DEPARTMENT)  2011         VICTOR WYRSCH
# 5       28  BATTALION CHIEF, (FIRE DEPARTMENT)  2011        RAYMOND GUZMAN
# 6       35  BATTALION CHIEF, (FIRE DEPARTMENT)  2011             JOSE VELO
# 7       40  BATTALION CHIEF, (FIRE DEPARTMENT)  2011          BRENDAN WARD
# 8       41  BATTALION CHIEF, (FIRE DEPARTMENT)  2011      MICHAEL THOMPSON
# 9       42  BATTALION CHIEF, (FIRE DEPARTMENT)  2011         THOMAS ABBOTT
# 10      47  BATTALION CHIEF, (FIRE DEPARTMENT)  2011      BRYAN RUBENSTEIN
# 11      51  BATTALION CHIEF, (FIRE DEPARTMENT)  2011       KIRK RICHARDSON
# 12      58           ASSISTANT DEPUTY CHIEF II  2011          MARK KEARNEY
# 13      64  BATTALION CHIEF, (FIRE DEPARTMENT)  2011         CHARLES CRANE
# 14      77  BATTALION CHIEF, (FIRE DEPARTMENT)  2011           KEVIN BURKE
# 15      80  BATTALION CHIEF, (FIRE DEPARTMENT)  2011      EDUARDO GONZALEZ
# 16      83  BATTALION CHIEF, (FIRE DEPARTMENT)  2011          LORRIE KALOS
# 17      87  BATTALION CHIEF, (FIRE DEPARTMENT)  2011        MICHAEL BRYANT
# 18      91  BATTALION CHIEF, (FIRE DEPARTMENT)  2011         MARK GONZALES
# 19      95  BATTALION CHIEF, (FIRE DEPARTMENT)  2011              REX HALE
# 20      98  BATTALION CHIEF, (FIRE DEPARTMENT)  2011           KEVIN SMITH
# 21     101  BATTALION CHIEF, (FIRE DEPARTMENT)  2011          KEVIN TAYLOR
# 22     107  BATTALION CHIEF, (FIRE DEPARTMENT)  2011            SAMSON LAI
# 23     119  BATTALION CHIEF, (FIRE DEPARTMENT)  2011           KHAIRUL ALI
# 24     128  BATTALION CHIEF, (FIRE DEPARTMENT)  2011           JOHN HICKEY
# 25   36161                     Chief of Police  2012          Gregory Suhr
# 26   36163              Chief, Fire Department  2012    Joanne Hayes-White
# 27   72926                     Chief of Police  2013        Gregory P Suhr
# 28   72927              Chief, Fire Department  2013  Joanne M Hayes-White
# 29  110535                     Chief of Police  2014        Gregory P Suhr
# 30  110536              Chief, Fire Department  2014  Joanne M Hayes-White
#
#       BasePay   TotalPay
# 0   118602.00  316285.74
# 1   176932.64  303427.55
# 2   174872.64  286347.05
# 3   168692.63  276434.22
# 4   168692.63  270672.63
# 5   168692.59  265463.46
# 6   177781.25  258364.22
# 7   147158.85  251685.16
# 8   168692.66  250595.39
# 9   168692.63  250408.49
# 10  168692.64  249293.30
# 11  168692.59  247254.61
# 12  217410.80  240019.10
# 13  168692.62  238479.28
# 14  174872.64  232007.77
# 15  168692.62  231592.25
# 16  168692.62  230906.51
# 17  150464.82  230459.00
# 18  188842.37  229060.63
# 19  168692.62  227318.90
# 20  168692.67  226357.33
# 21  168692.65  223852.35
# 22  149362.86  221049.32
# 23  150432.85  218793.75
# 24  168692.63  216981.27
# 25  302578.00  321552.11
# 26  296943.01  314759.60
# 27  319275.01  339282.07
# 28  313686.01  336922.01
# 29  307450.04  326716.76
# 30  302068.00  326233.44

# %% [markdown]
# ## 4.Introduction to NULL and IS NULL
#
# In SQL, NULL represents a missing or unknown value. You can check for NULL values using the expression IS NULL. For example, to count the number of missing `overtime_pay` in the `salaries` table:

# %%
SQL_salaries = pd.read_sql(
    """
        SELECT Count(OvertimePay)
        FROM Salaries
        WHERE OvertimePay IS NULL
    """, con = conn_2)
SQL_salaries
# Out:
#    Count(OvertimePay)
# 0               77321

# %% [markdown]
# As you can see, **IS NULL** is useful when combined with **WHERE** to figure out what data you're missing.
#
# Sometimes, you'll want to filter out missing values so you only get results which are not **NULL**. To do this, you can use the **IS NOT NULL** operator.
#
# For example, the following query gives the `Overtimepay` of all employee did not missing in the people table.

# %%
SQL_salaries = pd.read_sql(
    """
        SELECT Count(OvertimePay)
        FROM Salaries
        WHERE OvertimePay IS NOT NULL
    """, con = conn_2)
SQL_salaries
# Out:
#    Count(OvertimePay)
# 0               71332

# %% [markdown]
# This indicates that there are 71332 observations in `Salaries` data didn't got the missing-values at column `Overtime-Pay`

# %%
SQL_salaries = pd.read_sql(
    """
        SELECT Count(Status)
        FROM Salaries
        WHERE Status IS NOT NULL
    """, con = conn_2)
SQL_salaries
# Out:
#    Count(Status)
# 0          15785

# %% [markdown]
# Hence, only 15787 observations in `salaries database` have the available `Status` (look back line In [6])

# %% [markdown]
# ## 5. LIKE & NOT LIKE
#
# As you've seen, the **WHERE clause** can be used to filter **`text data`**.
#
# However, so far you've only been able to filter by specifying the exact text you're interested in. In the real world, often you'll want to search for a pattern rather than a `specific text string`.
#
# In SQL, the **LIKE** operator can be used in a **WHERE clause to search for a pattern in a column**. To accomplish this, you use something called a wildcard as a placeholder for some other values. There are two wildcards you can use with LIKE:
#
# The `% wildcard` will match `zero`, `one`, or `many characters in text`.
#
# For example, the following query matches companies like `'Nurse', 'Nurse Manager', 'Nurse Preactitioner'` and so on:

# %%
SQL_salaries = pd.read_sql(
    """
        SELECT EmployeeName, JobTitle
        FROM Salaries
        WHERE JobTitle LIKE 'Nurse%'
        AND EmployeeName LIKE 'T%'
    """, con = conn_2)
SQL_salaries
# Out:
#            EmployeeName            JobTitle
# 0         TROY WILLIAMS       NURSE MANAGER
# 1            TWYILA LAY  NURSE PRACTITIONER
# 2       TAE-WOL STANLEY  NURSE PRACTITIONER
# 3       TERRI ELLENBERG       NURSE MANAGER
# 4      TERESITA BALUYUT       NURSE MANAGER
# 5             TINA KING  NURSE PRACTITIONER
# 6           TAMARA OOMS  NURSE PRACTITIONER
# 7         THOMAS HOLTON       NURSE MANAGER
# 8          TAMAR BESSON  NURSE PRACTITIONER
# 9         THOMAS FARLEY  NURSE PRACTITIONER
# 10         TAMAR BESSON  NURSE PRACTITIONER
# 11    TERRENCE MARCOTTE  NURSE PRACTITIONER
# 12          TAMARA OOMS  NURSE PRACTITIONER
# 13           Twyila Lay  Nurse Practitioner
# 14        Troy Williams       Nurse Manager
# 15      Tae Wol Stanley  Nurse Practitioner
# 16      Terri Ellenberg       Nurse Manager
# 17        Thomas Holton       Nurse Manager
# 18          Tamara Ooms  Nurse Practitioner
# 19            Tina King  Nurse Practitioner
# 20         Tamar Besson  Nurse Practitioner
# 21        Thomas Farley  Nurse Practitioner
# 22           Tim Weiant  Nurse Practitioner
# 23    Terrence Marcotte  Nurse Practitioner
# 24          Tamara Ooms  Nurse Practitioner
# 25         Tamar Besson  Nurse Practitioner
# 26          Twyila  Lay  Nurse Practitioner
# 27      Troy S Williams       Nurse Manager
# 28    Tae Wol O Stanley  Nurse Practitioner
# 29    Terri L Ellenberg       Nurse Manager
# 30      Thomas G Holton       Nurse Manager
# 31        Tamara C Ooms  Nurse Practitioner
# 32          Tina M King  Nurse Practitioner
# 33         Tim A Weiant  Nurse Practitioner
# 34  Terrence R Marcotte  Nurse Practitioner
# 35       Tamar S Besson  Nurse Practitioner
# 36  Terrence R Marcotte  Nurse Practitioner
# 37       Tamar S Besson  Nurse Practitioner
# 38        Tamara C Ooms  Nurse Practitioner
# 39      Thomas G Holton       Nurse Manager
# 40           Twyila Lay  Nurse Practitioner
# 41    Tae Wol O Stanley  Nurse Practitioner
# 42    Terri L Ellenberg       Nurse Manager
# 43          Tina M King  Nurse Practitioner
# 44    Terilyn A Voegtle  Nurse Practitioner
# 45        Tamara C Ooms  Nurse Practitioner
# 46  Terrence R Marcotte  Nurse Practitioner
# 47  Terrence R Marcotte  Nurse Practitioner
# 48       Tamar S Besson  Nurse Practitioner
# 49         Tim A Weiant  Nurse Practitioner
# 50  Terrence R Marcotte  Nurse Practitioner
# 51       Tamar S Besson  Nurse Practitioner

# %% [markdown]
# The `_ wildcard` will match a single character.
#
# For example, the following query **'C_m %'** matches `JobTitle` like `'Commander', 'Camp', 'Communication'`while **NOT LIKE "N%"** will return the `EmployeeName` that didn't starting by the letter `N`

# %%
SQL_salaries = pd.read_sql(
    """
        SELECT EmployeeName, JobTitle
        FROM Salaries
        WHERE JobTitle LIKE 'C_m%'
        AND EmployeeName NOT LIKE 'N%'
    """, con = conn_2)
SQL_salaries
# Out:
#           EmployeeName                            JobTitle
# 0      RICHARD CORRIEA  COMMANDER III, (POLICE DEPARTMENT)
# 1          SANDRA TONG  COMMANDER III, (POLICE DEPARTMENT)
# 2          L MILITELLO  COMMANDER III, (POLICE DEPARTMENT)
# 3         MICHAEL BIEL  COMMANDER III, (POLICE DEPARTMENT)
# 4           MIKAIL ALI  COMMANDER III, (POLICE DEPARTMENT)
# ...                ...                                 ...
# 1717  Addison G Wright                      Camp Assistant
# 1718   Marshall Robles      Community Police Services Aide
# 1719   Larry Liederman            Commissioner No Benefits
# 1720   Andre M Johnson         Communications Dispatcher 1
# 1721    Joann Anderson         Communications Dispatcher 2
#
# [1722 rows x 2 columns]
